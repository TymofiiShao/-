# %% [markdown]
# ## Завдання.
# 1. Згенерувати N тривимiрних незалежних випадкових векторiв, в яких координати незалежнi,
# першi двi координати мають показниковий розподiл з параметром 1, третя координата має
# стандартний нормальний розподiл.
#
# 2. Реалiзувати алгоритм Козинця пошуку роздiляючого вектора для опуклої оболонки згенеро-
# ваних векторiв. Алгоритм має працювати для довiльного N.

# %%
import numpy as np
from scipy.optimize import golden

# %%
def generate_vectors(n):
    
    return np.column_stack([
        np.random.exponential(scale=1, size=(n, 1)),
        np.random.exponential(scale=1, size=(n, 1)),
        np.random.normal(scale=1, size=(n, 1))
    ])

# %%
def kozinets_algorithm(vectors, separating_vector):
    
    for j, vector in enumerate(vectors):
        scalar_product = np.dot(vector, separating_vector)
        
        if scalar_product <= 0:
            print(f"Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0")
            print(f"j: {j}, \nx^j: {vector}, \na_t: {separating_vector}, \nscalar_product: {scalar_product}")
            
            def objective(k):
                
                return np.linalg.norm((1 - k) * separating_vector + k * vector)

            optimal_k = golden(objective, full_output=True)[0]
            new_vector = (1 - optimal_k) * separating_vector + optimal_k * vector
            
            print("a_t1: ", new_vector, "\n")
            
            return kozinets_algorithm(vectors, new_vector)
    
    return separating_vector

# %%
def main():
    try:
        n = int(input("Введіть кількість векторів (n): "))
        if n <= 0:
            raise ValueError("Кількість векторів має бути більше нуля.")
    except ValueError as e:
        print(f"Помилка вводу: {e}")
        return
    
    vectors = generate_vectors(n)
    
    print("\nЗгенеровані вектори:")
    print(vectors[:10]) 
    
    initial_vector = vectors[0]
    separating_vector = kozinets_algorithm(vectors, initial_vector)
    
    print("\nРозділяючий вектор: ", separating_vector)

# %%
if __name__ == "__main__":
    main()
# Out:
# Введіть кількість векторів (n): 57
#
# Згенеровані вектори:
# [[ 0.03097315  0.02242753  1.05140369]
#  [ 0.46159911  0.76678178 -0.16749676]
#  [ 0.74552934  0.45280636 -1.78275042]
#  [ 2.34539548  1.63850008 -0.66159801]
#  [ 0.78368305  1.42595214  0.12726013]
#  [ 2.0461182   0.4955633   1.04809432]
#  [ 1.11901889  2.04456729  0.9516142 ]
#  [ 0.20108005  0.06515971  0.8295498 ]
#  [ 0.42753741  0.07397087  1.20664462]
#  [ 0.09286388  0.04570456 -1.23416187]]
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 1,
# x^j: [ 0.46159911  0.76678178 -0.16749676],
# a_t: [0.03097315 0.02242753 1.05140369],
# scalar_product: -0.14461250848048945
# a_t1:  [0.27316893 0.44107266 0.36586085]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 2,
# x^j: [ 0.74552934  0.45280636 -1.78275042],
# a_t: [0.27316893 0.44107266 0.36586085],
# scalar_product: -0.24886262309526286
# a_t1:  [0.33679228 0.4426531  0.07645928]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.33679228 0.4426531  0.07645928],
# scalar_product: -0.04285602567075529
# a_t1:  [ 0.29164845  0.36918984 -0.16609736]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.29164845  0.36918984 -0.16609736],
# scalar_product: -0.15732208578365758
# a_t1:  [0.22825165 0.28485648 0.13000158]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.22825165 0.28485648 0.13000158],
# scalar_product: -0.12622741345244734
# a_t1:  [ 0.20892928  0.25072503 -0.06469008]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.20892928  0.25072503 -0.06469008],
# scalar_product: -0.05592104718185024
# a_t1:  [0.18662604 0.22211251 0.0751899 ]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.18662604 0.22211251 0.0751899 ],
# scalar_product: -0.06531413612727854
# a_t1:  [ 0.17833482  0.20651306 -0.04059383]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.17833482  0.20651306 -0.04059383],
# scalar_product: -0.0325253330086686
# a_t1:  [0.1655093  0.19049131 0.0544474 ]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.1655093  0.19049131 0.0544474 ],
# scalar_product: -0.04312074324541756
# a_t1:  [ 0.1607819   0.18106931 -0.02940884]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.1607819   0.18106931 -0.02940884],
# scalar_product: -0.021879705451253447
# a_t1:  [0.15205255 0.170401   0.04327343]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.15205255 0.170401   0.04327343],
# scalar_product: -0.03149812800350404
# a_t1:  [ 0.14898618  0.1639409  -0.02290616]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.14898618  0.1639409  -0.02290616],
# scalar_product: -0.015792262542757413
# a_t1:  [0.14249097 0.15615227 0.03622179]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.14249097 0.15615227 0.03622179],
# scalar_product: -0.02433441721315693
# a_t1:  [ 0.14034766  0.15138223 -0.01864387]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.14034766  0.15138223 -0.01864387],
# scalar_product: -0.01186009473279279
# a_t1:  [0.13523848 0.14535841 0.03134094]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.13523848 0.14535841 0.03134094],
# scalar_product: -0.019477478428260236
# a_t1:  [ 0.13366566  0.14165954 -0.0156309 ]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.13366566  0.14165954 -0.0156309 ],
# scalar_product: -0.009117268981558468
# a_t1:  [0.12949065 0.13681211 0.0277499 ]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.12949065 0.13681211 0.0277499 ],
# scalar_product: -0.015969926556114157
# a_t1:  [ 0.12829666  0.13384211 -0.01338693]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.12829666  0.13384211 -0.01338693],
# scalar_product: -0.007099565095377992
# a_t1:  [0.12478892 0.1298265  0.02499032]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.12478892 0.1298265  0.02499032],
# scalar_product: -0.01332005827454701
# a_t1:  [ 0.12385992  0.12737859 -0.01165036]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.12385992  0.12737859 -0.01165036],
# scalar_product: -0.005556108083196273
# a_t1:  [0.1208498  0.12397751 0.02279933]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.1208498  0.12397751 0.02279933],
# scalar_product: -0.011249144102211759
# a_t1:  [ 0.1201136   0.12191846 -0.01026636]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.1201136   0.12191846 -0.01026636],
# scalar_product: -0.0043394565728224815
# a_t1:  [0.11748714 0.11898703 0.02101499]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.11748714 0.11898703 0.02101499],
# scalar_product: -0.009587339564598632
# a_t1:  [ 0.11689563  0.11722661 -0.00913736]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.11689563  0.11722661 -0.00913736],
# scalar_product: -0.003357327315495746
# a_t1:  [0.11457291 0.11466394 0.01953194]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.11457291 0.11466394 0.01953194],
# scalar_product: -0.008225227436929206
# a_t1:  [ 0.11409272  0.11313861 -0.00819882]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.11409272  0.11313861 -0.00819882],
# scalar_product: -0.0025490415834220313
# a_t1:  [0.11201573 0.11087192 0.01827856]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.11201573 0.11087192 0.01827856],
# scalar_product: -0.0070891379098980654
# a_t1:  [ 0.11162297  0.10953547 -0.00740628]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.11162297  0.10953547 -0.00740628],
# scalar_product: -0.0018730640714531496
# a_t1:  [0.10974836 0.10751076 0.01720444]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.10974836 0.10751076 0.01720444],
# scalar_product: -0.006127667512838178
# a_t1:  [ 0.10942544  0.10632871 -0.00672814]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.10942544  0.10632871 -0.00672814],
# scalar_product: -0.0013000486611935529
# a_t1:  [0.10772009 0.1045049  0.01627299]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.10772009 0.1045049  0.01627299],
# scalar_product: -0.005303851881324428
# a_t1:  [ 0.10745379  0.1034509  -0.00614131]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.10745379  0.1034509  -0.00614131],
# scalar_product: -0.0008086624119430213
# a_t1:  [0.10589181 0.10179615 0.01545706]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.10589181 0.10179615 0.01545706],
# scalar_product: -0.004590444985225305
# a_t1:  [ 0.10567199  0.10084968 -0.00562852]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.10567199  0.10084968 -0.00562852],
# scalar_product: -0.0003830442585645612
# a_t1:  [0.10423286 0.09933882 0.01473601]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.10423286 0.09933882 0.01473601],
# scalar_product: -0.003966918230394767
# a_t1:  [ 0.10405159  0.09848366 -0.00517661]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 0,
# x^j: [0.03097315 0.02242753 1.05140369],
# a_t: [ 0.10405159  0.09848366 -0.00517661],
# scalar_product: -1.115901539766248e-05
# a_t1:  [0.10271874 0.09709651 0.01409388]
#
# Знайдений вектор x^j задовольняє умову (a_t, x^j) <= 0
# j: 9,
# x^j: [ 0.09286388  0.04570456 -1.23416187],
# a_t: [0.10271874 0.09709651 0.01409388],
# scalar_product: -0.0034175098737136873
# a_t1:  [ 0.10256977  0.09631964 -0.00477536]
#
#
# Розділяючий вектор:  [ 0.10256977  0.09631964 -0.00477536]
